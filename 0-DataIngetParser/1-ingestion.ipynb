# %%
import os
from dotenv import load_dotenv
load_dotenv()

if os.environ['OPENAI_API_KEY']:
    print("API Key is set.")
# Out:
# API Key is set.

# %% [markdown]
# ### Introduction to data ingestion

# %%
import os
from typing import List, Dict, Any
import pandas as pd

# %%
from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter, CharacterTextSplitter, TokenTextSplitter
print("Set Up Completed")
# Out:
# Set Up Completed

# %% [markdown]
# Understanding Document Structure in Langchain

# %%
## creat a simple document
doc=Document(
    page_content="This is the main text content that will be embedded and searched.",
    metadata = {
        "source":"example.txt",
        "page":1,
        "author":"Rohid Jan",
    }
)
print("Document Strructure")
print(f"content : {doc.page_content}")
print(f"metadat : {doc.metadata}")
# Out:
# Document Strructure
# content : This is the main text content that will be embedded and searched.
# metadat : {'source': 'example.txt', 'page': 1, 'author': 'Rohid Jan'}

# %%
type(doc)
# Out:
# langchain_core.documents.base.Document

# %% [markdown]
# ### Text file (.txt) - the simplest case{#2-text-file}

# %%
## creat a simple txt file
import os
os.makedirs("data/text_files", exist_ok=True)

# %%
sample_text = {
    "data/text_files/python_intro.txt": """Python programming introduction
    
klcjaskchjkzxLjvhiuysdgviospouhgcisdgcsiuhg sfhise ewuhfusehf uwgduiesf  iohgdfwiehf
efkjioehyfuikjhjslkjfhghwio ifdiewhdf uhyqwugd uihdfuiwegfyue qudgywgf.""",

    "data/text_files/machin_learning.txt": """Machin learning basics
    
jkwfgjhf eufhjkd hejkljgf sdnhchj fk fhuiewgdf kljkuwddg ewf
ofihuwfyiejfkjkjchahsockihfjplekijvhudskvposdjhuvkodfskhvldfskvojewd.
"""
}
for filepath,content in sample_text.items():
    with open(filepath, "w", encoding="utf-8") as f:
        f.write(content)

print("sample text files created!")
# Out:
# sample text files created!

# %% [markdown]
# ### TextLodear- Read single file

# %%
from langchain_community.document_loaders import TextLoader

##loading a single text file
loader = TextLoader("data/text_files/python_intro.txt", encoding="utf-8")

documents = loader.load()
print(f"loaded {len(documents)} document")
print(f"content preview: {documents[0].page_content[:50]}...")
print(f"metadata: {documents[0].metadata}")
# Out:
# loaded 1 document
# content preview: Python programming introduction
#
# klcjaskchjkzxLjvh...
# metadata: {'source': 'data/text_files/python_intro.txt'}

# %% [markdown]
# ### DirectoryLoader- Multiple text files

# %%
from langchain_community.document_loaders import DirectoryLoader

## load all the text files from the directory
dir_loader = DirectoryLoader(
    "data/text_files",
    glob="**/*.txt",
    loader_cls= TextLoader,
    loader_kwargs={'encoding': 'utf-8'},
    show_progress = True
)

documents = dir_loader.load()
print(f"loaded {len(documents)} documenrs")
for i, doc in enumerate(documents):
    print(f"\nDocument {i+1}:")
    print(f" source: {doc.metadata["source"]}")
    print(f" lenght: {len(doc.page_content)} characters")
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 316.80it/s]
# loaded 2 documenrs
#
# Document 1:
#  source: data\text_files\machin_learning.txt
#  lenght: 155 characters
#
# Document 2:
#  source: data\text_files\python_intro.txt
#  lenght: 189 characters

# %% [markdown]
# ### Introduction to Data Ingestion

# %%
import os
from typing import List, Dict, Any
import pandas as pd

# %%
from langchain_core.documents import Document
from langchain_text_splitters import(
    RecursiveCharacterTextSplitter,
    CharacterTextSplitter,
    TokenTextSplitter
)
print("Set up completed!")
# Out:
# Set up completed!

# %% [markdown]
# ### Understanding Document Structure In Langchain

# %%
## creat a simple document
doc=Document(
    page_content="This is the main text content that will be embedded and searched.",
    metadata={
        "source":"example.txt",
        "page":1,
        "author":"Rohid Jan",
        "data_created":"2026-01-01",
        "custom_field":"any_value"
    }
)
print("Document Structure")

print(f"Content :{doc.page_content}")
print(f"Metadata :{doc.metadata}")
# Out:
# Document Structure
# Content :This is the main text content that will be embedded and searched.
# Metadata :{'source': 'example.txt', 'page': 1, 'author': 'Rohid Jan', 'data_created': '2026-01-01', 'custom_field': 'any_value'}

# %% [markdown]
# ### Text Files(.txt)-The Simple Case {#2-text-files}

# %%
## creayt a simple text file
import os
os.makedirs("data/text_files", exist_ok=True)

# %%
sample_text={
    "data/text_files/python_intro.txt":"""Python Programming Introduction
    
Python is an interpreted language, which means you don’t need to compile your code before running it. This makes development faster and easier, especially for beginners who want to quickly test their ideas.

Another important feature of Python is its large community and rich ecosystem of libraries. There are many pre-built libraries that help you perform complex tasks without writing everything from scratch. For example:

NumPy for numerical computing
Pandas for data analysis
Matplotlib for visualization
TensorFlow and PyTorch for machine learning

Python is also cross-platform, meaning you can run your code on Windows, macOS, or Linux without major changes.""",

    "data/text_files/machin_learning.txt":"""Machin learning basics

Instead of writing detailed rules for a computer to follow, in machine learning you provide data and let the system find patterns on its own. For example, if you want a computer to recognize spam emails, you don’t write all possible spam rules—instead, you train a model using many examples of spam and non-spam emails. The system then learns how to classify new emails.

There are three main types of machine learning:

1. Supervised Learning
In this type, the model is trained using labeled data. This means each example comes with a correct answer. For instance, predicting house prices based on features like size, location, and number of rooms.

2. Unsupervised Learning
Here, the model works with unlabeled data and tries to find hidden patterns or groupings. An example is customer segmentation, where users are grouped based on behavior without predefined categories.

3. Reinforcement Learning
In this approach, an agent learns by interacting with an environment and receiving rewards or penalties. It improves its performance over time by maximizing rewards. This is commonly used in robotics and game-playing AI.

    """
}

for filepath,content in sample_text.items():
    with open(filepath, 'w', encoding="utf-8") as f:
        f.write(content)

print("✅ sample text file created")
# Out:
# ✅ sample text file created

# %% [markdown]
# ### TextLoader- Read Single File

# %%
from langchain_community.document_loaders import TextLoader

## loading a single text file
loader = TextLoader("data/text_files/python_intro.txt", encoding="utf-8")

documents = loader.load()
print(f"📄Loaded {len(documents)} documents")
print(f"Content previwe: {documents[0].page_content[:100]}...")
print(f"Metadata: {documents[0].metadata}")
# Out:
# 📄Loaded 1 documents
# Content previwe: Python Programming Introduction
#
# Python is an interpreted language, which means you don’t need to co...
# Metadata: {'source': 'data/text_files/python_intro.txt'}

# %% [markdown]
# ### DirectoryLoader- Multiple Text Files

# %%
from langchain_community.document_loaders import DirectoryLoader

## load al, the text files from the directory
dir_loader = DirectoryLoader(
    "data/text_files",
    glob="**/*.txt", ##pattern to match files
    loader_cls= TextLoader,
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=True
)

documents = dir_loader.load()

print(f"📂 Loaded {len(documents)} documents")
for i, doc in enumerate(documents):
    print(f"\nDocuments {i+1}:")
    print(f" Source: {doc.metadata['source']}")
    print(f" Lenght: {len(doc.page_content)} charecters")
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 179.59it/s]
# 📂 Loaded 2 documents
#
# Documents 1:
#  Source: data\text_files\machin_learning.txt
#  Lenght: 1153 charecters
#
# Documents 2:
#  Source: data\text_files\python_intro.txt
#  Lenght: 699 charecters

# %% [markdown]
# ### Text Splitting

# %%
### diffrent text splitting strategies
from langchain_text_splitters import (
    CharacterTextSplitter,
    RecursiveCharacterTextSplitter,
    TokenTextSplitter
)
print(documents)
# Out:
# [Document(metadata={'source': 'data\\text_files\\machin_learning.txt'}, page_content='Machin learning basics\n\nInstead of writing detailed rules for a computer to follow, in machine learning you provide data and let the system find patterns on its own. For example, if you want a computer to recognize spam emails, you don’t write all possible spam rules—instead, you train a model using many examples of spam and non-spam emails. The system then learns how to classify new emails.\n\nThere are three main types of machine learning:\n\n1. Supervised Learning\nIn this type, the model is trained using labeled data. This means each example comes with a correct answer. For instance, predicting house prices based on features like size, location, and number of rooms.\n\n2. Unsupervised Learning\nHere, the model works with unlabeled data and tries to find hidden patterns or groupings. An example is customer segmentation, where users are grouped based on behavior without predefined categories.\n\
# ...

# %%
text = documents[0].page_content
text
# Out:
# 'Machin learning basics\n\nInstead of writing detailed rules for a computer to follow, in machine learning you provide data and let the system find patterns on its own. For example, if you want a computer to recognize spam emails, you don’t write all possible spam rules—instead, you train a model using many examples of spam and non-spam emails. The system then learns how to classify new emails.\n\nThere are three main types of machine learning:\n\n1. Supervised Learning\nIn this type, the model is trained using labeled data. This means each example comes with a correct answer. For instance, predicting house prices based on features like size, location, and number of rooms.\n\n2. Unsupervised Learning\nHere, the model works with unlabeled data and tries to find hidden patterns or groupings. An example is customer segmentation, where users are grouped based on behavior without predefined categories.\n\n3. Reinforcement Learning\nIn this approach, an agent learns by interacting with an 
# ...

# %%
## method1 charecter text splitting
print("1️⃣charecter text splitter")
char_splitter = CharacterTextSplitter(
    separator="\n", # split on newlines
    chunk_size=200, #max chunk size in charecters
    chunk_overlap=2, #overlap bettween chunk
    length_function=len #how to measure chunk size
)

char_chunks = char_splitter.split_text(text)
print(f"Created {len(char_chunks)} chunks")
print(f"First chunk: {char_chunks[1]}...")
# Out:
# Created a chunk of size 370, which is longer than the specified 200
# Created a chunk of size 205, which is longer than the specified 200
# Created a chunk of size 220, which is longer than the specified 200
# 1️⃣charecter text splitter
# Created 8 chunks
# First chunk: Instead of writing detailed rules for a computer to follow, in machine learning you provide data and let the system find patterns on its own. For example, if you want a computer to recognize spam emails, you don’t write all possible spam rules—instead, you train a model using many examples of spam and non-spam emails. The system then learns how to classify new emails....

# %%
print(char_chunks[0])
print("--------------")
print(char_chunks[1])
print("--------------")
print(char_chunks[2])
print("--------------")
# Out:
# Machin learning basics
# --------------
# Instead of writing detailed rules for a computer to follow, in machine learning you provide data and let the system find patterns on its own. For example, if you want a computer to recognize spam emails, you don’t write all possible spam rules—instead, you train a model using many examples of spam and non-spam emails. The system then learns how to classify new emails.
# --------------
# There are three main types of machine learning:
# 1. Supervised Learning
# --------------

# %%
# method 2: recursive charecter text splitting (recomended)
print("\n2️⃣ RECHURSIVE CHARECTER TEXT SPLITTER")
recursive_splitter = RecursiveCharacterTextSplitter(
    separators=["\n\n","\n", " ", ""], # try this separators in order
    chunk_size = 200,
    chunk_overlap=20,
    length_function = len
)

recursive_chunks = recursive_splitter.split_text(text)
print(f"Created {len(recursive_chunks)} chunks")
print(f"First chunk: {recursive_chunks[0][:100]}...")
# Out:
# 2️⃣ RECHURSIVE CHARECTER TEXT SPLITTER
# Created 12 chunks
# First chunk: Machin learning basics...

# %%
print(recursive_chunks[0])
print("-----------------")
print(recursive_chunks[1])
print("-----------------")
print(recursive_chunks[2])
print("-----------------")
print(recursive_chunks[3])
print("-----------------")
# Out:
# Machin learning basics
# -----------------
# Instead of writing detailed rules for a computer to follow, in machine learning you provide data and let the system find patterns on its own. For example, if you want a computer to recognize spam
# -----------------
# to recognize spam emails, you don’t write all possible spam rules—instead, you train a model using many examples of spam and non-spam emails. The system then learns how to classify new emails.
# -----------------
# There are three main types of machine learning:
# -----------------

# %%
# method 3: token-based splitting
print("\n3️⃣ TOKEN TEXT SPLITTER")
token_splitter = TokenTextSplitter(
    chunk_size=50, #size in tokens not charecter
    chunk_overlap=10
)

token_chunks = token_splitter.split_text(text)
print(f"Created {len(token_chunks)} chunks")
print(f"First chunk: {token_chunks[0][:100]}...")
# Out:
# 3️⃣ TOKEN TEXT SPLITTER
# Created 6 chunks
# First chunk: Machin learning basics
#
# Instead of writing detailed rules for a computer to follow, in machine learn...
